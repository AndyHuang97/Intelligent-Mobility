# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster, inconsistent
from scipy.spatial.distance import cdist, pdist

import matplotlib.pyplot as plt
# %matplotlib inline

algo = "HC"
base_path = "/content/drive/MyDrive/MIDA2/IntelligentMobilityProject/"
pictures_path = f"{base_path}Pictures/"
dataset_path = f"{base_path}Survey+dataset/"
code_path = f"{base_path}Code/"
results_path = f"{base_path}Code/Data/"
HC_base_path = f"{results_path}{algo}/"
numpy_file_type = ".npy"
image_file_type = ".html"

import sys
sys.path.append(code_path)
np.set_printoptions(precision=5, suppress=True)

# %% [markdown]
# # Merge cuts

# %%
np.set_printoptions(threshold=sys.maxsize)

# %%
metric = "VDM"
vars = 5
link = "complete"
n_clusters = 5
print(metric, vars, link)
# Out:
# VDM 5 complete

# %%
HC_path = f"{HC_base_path}{metric}{vars}/{algo}_{metric}_{link}{numpy_file_type}"
Z = {}
Z[metric] = np.load(HC_path)
cluster_labels = fcluster(Z[metric], n_clusters, criterion='maxclust')

# %%
non_zero_distance_merges = Z[metric][:,2] > 0
#print(Z[metric][non_zero_distance_merges])
print(Z[metric][non_zero_distance_merges].shape)
# Out:
# (3292, 4)

# %% [markdown]
# # Merge cuts

# %%
import postprocessing.merge_cuts
import importlib
importlib.reload(postprocessing.merge_cuts)
# Out:
# <module 'postprocessing.merge_cuts' from '/content/drive/MyDrive/MIDA2/IntelligentMobilityProject/Code/postprocessing/merge_cuts.py'>

# %%
from postprocessing.merge_cuts import merge_multiple_cuts

# %%
k_values = [4, 6, 8]

merged_cuts = merge_multiple_cuts(Z[metric], k_values)
print(np.unique(merged_cuts, return_counts=True))
# Out:
# k1: [1 2 3 4]
# k2: [5, 6]
# k1: [ 1  2  3 10 11]
# k2: [5, 6]
# (array([ 1,  2, 10, 11, 17, 18], dtype=int32), array([1486,  514, 5734, 8969, 3279, 6623]))

# %% [markdown]
# # Plot silhouette

# %%
metric = "VDM"
vars = 6

# %%
ds_path = f'{dataset_path}4_DNA_{vars}values_normalized.csv'
df_DNA = pd.read_csv(ds_path)

# %%
import metrics.silhouette
import plots.silhouette
import importlib
importlib.reload(metrics.silhouette) 
importlib.reload(plots.silhouette)
# Out:
# <module 'plots.silhouette' from '/content/drive/MyDrive/MIDA2/IntelligentMobilityProject/Code/plots/silhouette.py'>

# %%
from metrics.silhouette import getSilhouette
from plots.silhouette import plotSilhouette
from plotly.subplots import make_subplots
from metrics.elbow import getElbows

# %%
link = "average"
postprocessing = False
is_postprocessing = "_fix" if postprocessing else ""
print(metric, vars, link, "postprocessing:", postprocessing)
range_min = 2
range_max = 100
# Out:
# VDM 6 average postprocessing: False

# %%
from plots.silhouette import plot_silhouette_merge_k_values

# %%
vars_values = [5,6]
linkages = ["complete", "average", "weighted"]
postprocessing_values = [False, True]
for vars in vars_values:
  ds_path = f'{dataset_path}4_DNA_{vars}values_normalized.csv'
  df_DNA = pd.read_csv(ds_path)
  try:
    del distance_matrix
  except:
    distance_matrix = []
  distance_matrix = np.load(f"{results_path}distance_matrix_{metric}{vars}.npy")
  for link in linkages:
    WSS_path = f"{HC_base_path}{metric}{vars}/WSS/WSS_{metric}_{link}_range({range_min},{range_max}){numpy_file_type}"
    wss = np.load(WSS_path)
    k_values = getElbows(wss, range_min, add_first_k=True)
    HC_path = f"{HC_base_path}{metric}{vars}/{algo}_{metric}_{link}{numpy_file_type}"
    Z = {}
    Z[metric] = np.load(HC_path)
    for postprocessing in postprocessing_values:
      is_postprocessing = "_fix" if postprocessing else ""
      save_path = f"{pictures_path}HC/Silhouette/{metric}{vars}/MergedCuts/MergedCuts_{metric}_{link}_{str(k_values)}{is_postprocessing}.html"
      plot_silhouette_merge_k_values(df_DNA, distance_matrix, Z[metric], metric, link ,k_values, postprocessing, save_path=save_path)
# Out:
# /content/drive/MyDrive/MIDA2/IntelligentMobilityProject/Code/metrics/elbow.py:18: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# For n_clusters = 2 The average silhouette_score is : 0.6858174526302973
# k1: [1 2]
# k2: [3, 4]
# For n_clusters = 4 The average silhouette_score is : 0.30054295644899076
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# For n_clusters = 5 The average silhouette_score is : 0.26685395685491603
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# k1: [ 1  2  6 13 14]
# k2: [5, 6]
# For n_clusters = 6 The average silhouette_score is : 0.257384567501542
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# k1: [ 1  2  6 13 14]
# k2: [5, 6]
# k1: [ 1  2 13 14 20 21]
# k2: [13, 14]
# For n_clusters = 7 The average silhouette_score is : 0.20636338133930035
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# k1: [ 1  2  6 13 14]
# k2: [5, 6]
# k1: [ 1  2 13 14 20 21]
# k2: [13, 14]
# k1: [ 1  2 14 20 21 35 36]
# k2: [10, 11]
# For n_clusters = 8 The average silhouette_score is : 0.1888135119288355
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# k1: [ 1  2  6 13 14]
# k2: [5, 6]
# k1: [ 1  2 13 14 20 21]
# k2: [13, 14]
# k1: [ 1  2 14 20 21 35 36]
# k2: [10, 11]
# k1: [ 1  2 14 21 35 36 47 48]
# k2: [17, 18]
# For n_clusters = 10 The average silhouette_score is : 0.1764235795406722
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# k1: [ 1  2  6 13 14]
# k2: [5, 6]
# k1: [ 1  2 13 14 20 21]
# k2: [13, 14]
# k1: [ 1  2 14 20 21 35 36]
# k2: [10, 11]
# k1: [ 1  2 14 21 35 36 47 48]
# k2: [17, 18]
# k1: [ 1  2 14 21 35 36 47 48 66 67]
# k2: [29, 30]
# For n_clusters = 12 The average silhouette_score is : 0.17032796739864772
# For n_clusters = 2 The average silhouette_score is : 0.6858174526302973
# >>> After fix: For n_clusters = 2 (including outliers). The average silhouette_score is : 0.6858174526302973
# k1: [1 2]
# k2: [3, 4]
# For n_clusters = 4 The average silhouette_score is : 0.30054295644899076
# To be fixed len:  (346,)
# While fix: For n_clusters = 4 The average silhouette_score is : 0.3274112496977712
# To be fixed len:  (135,)
# While fix: For n_clusters = 4 The average silhouette_score is : 0.32737735024715725
# Score lowered, keeping previous iteration labels..
# >>> After fix: For n_clusters = 5 (including outliers). The average silhouette_score is : 0.33442118704161977
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# For n_clusters = 5 The average silhouette_score is : 0.26685395685491603
# To be fixed len:  (846,)
# While fix: For n_clusters = 5 The average silhouette_score is : 0.307131981677646
# To be fixed len:  (604,)
# While fix: For n_clusters = 5 The average silhouette_score is : 0.3123720371665581
# To be fixed len:  (712,)
# While fix: For n_clusters = 5 The average silhouette_score is : 0.31404633237348756
# >>> After fix: For n_clusters = 6 (including outliers). The average silhouette_score is : 0.3278913903214997
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# k1: [ 1  2  6 13 14]
# k2: [5, 6]
# For n_clusters = 6 The average silhouette_score is : 0.257384567501542
# To be fixed len:  (356,)
# While fix: For n_clusters = 6 The average silhouette_score is : 0.2887623205326058
# To be fixed len:  (151,)
# While fix: For n_clusters = 6 The average silhouette_score is : 0.2900756153584382
# >>> After fix: For n_clusters = 7 (including outliers). The average silhouette_score is : 0.2925445112101571
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# k1: [ 1  2  6 13 14]
# k2: [5, 6]
# k1: [ 1  2 13 14 20 21]
# k2: [13, 14]
# For n_clusters = 7 The average silhouette_score is : 0.20636338133930035
# To be fixed len:  (1293,)
# While fix: For n_clusters = 7 The average silhouette_score is : 0.2424962222588954
# To be fixed len:  (948,)
# While fix: For n_clusters = 7 The average silhouette_score is : 0.24385123756727511
# >>> After fix: For n_clusters = 8 (including outliers). The average silhouette_score is : 0.2574894420206733
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# k1: [ 1  2  6 13 14]
# k2: [5, 6]
# k1: [ 1  2 13 14 20 21]
# k2: [13, 14]
# k1: [ 1  2 14 20 21 35 36]
# k2: [10, 11]
# For n_clusters = 8 The average silhouette_score is : 0.1888135119288355
# To be fixed len:  (2647,)
# While fix: For n_clusters = 8 The average silhouette_score is : 0.23154190177857434
# To be fixed len:  (2125,)
# While fix: For n_clusters = 8 The average silhouette_score is : 0.24121187194898136
# To be fixed len:  (2154,)
# While fix: For n_clusters = 8 The average silhouette_score is : 0.24237148377771642
# >>> After fix: For n_clusters = 9 (including outliers). The average silhouette_score is : 0.2829214516634666
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# k1: [ 1  2  6 13 14]
# k2: [5, 6]
# k1: [ 1  2 13 14 20 21]
# k2: [13, 14]
# k1: [ 1  2 14 20 21 35 36]
# k2: [10, 11]
# k1: [ 1  2 14 21 35 36 47 48]
# k2: [17, 18]
# For n_clusters = 10 The average silhouette_score is : 0.1764235795406722
# To be fixed len:  (1653,)
# While fix: For n_clusters = 10 The average silhouette_score is : 0.2465357144160771
# To be fixed len:  (2239,)
# While fix: For n_clusters = 10 The average silhouette_score is : 0.2451262150611208
# Score lowered, keeping previous iteration labels..
# >>> After fix: For n_clusters = 11 (including outliers). The average silhouette_score is : 0.266961057228662
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [5, 6]
# k1: [ 1  2  6 13 14]
# k2: [5, 6]
# k1: [ 1  2 13 14 20 21]
# k2: [13, 14]
# k1: [ 1  2 14 20 21 35 36]
# k2: [10, 11]
# k1: [ 1  2 14 21 35 36 47 48]
# k2: [17, 18]
# k1: [ 1  2 14 21 35 36 47 48 66 67]
# k2: [29, 30]
# For n_clusters = 12 The average silhouette_score is : 0.17032796739864772
# To be fixed len:  (2908,)
# While fix: For n_clusters = 12 The average silhouette_score is : 0.24913764244601455
# To be fixed len:  (2616,)
# While fix: For n_clusters = 12 The average silhouette_score is : 0.2526449805434549
# To be fixed len:  (2359,)
# While fix: For n_clusters = 12 The average silhouette_score is : 0.25080535717799746
# Score lowered, keeping previous iteration labels..
# >>> After fix: For n_clusters = 13 (including outliers). The average silhouette_score is : 0.29810731403973845
# /content/drive/MyDrive/MIDA2/IntelligentMobilityProject/Code/metrics/elbow.py:18: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# For n_clusters = 2 The average silhouette_score is : 0.6858174526302973
# k1: [1 2]
# k2: [2, 3]
# For n_clusters = 3 The average silhouette_score is : 0.4407280676985771
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# For n_clusters = 4 The average silhouette_score is : 0.378107366107184
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# For n_clusters = 5 The average silhouette_score is : 0.3167876358294557
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# For n_clusters = 6 The average silhouette_score is : 0.3125951667044843
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# For n_clusters = 7 The average silhouette_score is : 0.28054958616496106
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# For n_clusters = 9 The average silhouette_score is : 0.2920364490526943
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 39 40 54 55]
# k2: [16, 17]
# For n_clusters = 11 The average silhouette_score is : 0.2928083991008779
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 39 40 54 55]
# k2: [16, 17]
# k1: [ 1  5 11 29 30 39 40 54 55 72 73]
# k2: [13, 14]
# For n_clusters = 12 The average silhouette_score is : 0.2761572775936626
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 39 40 54 55]
# k2: [16, 17]
# k1: [ 1  5 11 29 30 39 40 54 55 72 73]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 40 54 55 72 73 87 88]
# k2: [25, 26]
# For n_clusters = 13 The average silhouette_score is : 0.25137036877693864
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 39 40 54 55]
# k2: [16, 17]
# k1: [ 1  5 11 29 30 39 40 54 55 72 73]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 40 54 55 72 73 87 88]
# k2: [25, 26]
# k1: [  1   5  11  29  30  40  55  72  73  87  88 114 115]
# k2: [28, 29]
# For n_clusters = 14 The average silhouette_score is : 0.2564795266300811
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 39 40 54 55]
# k2: [16, 17]
# k1: [ 1  5 11 29 30 39 40 54 55 72 73]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 40 54 55 72 73 87 88]
# k2: [25, 26]
# k1: [  1   5  11  29  30  40  55  72  73  87  88 114 115]
# k2: [28, 29]
# k1: [  1   5  11  29  30  40  55  72  73  87  88 114 144 145]
# k2: [42, 43]
# For n_clusters = 15 The average silhouette_score is : 0.26169119179295375
# For n_clusters = 2 The average silhouette_score is : 0.6858174526302973
# >>> After fix: For n_clusters = 2 (including outliers). The average silhouette_score is : 0.6858174526302973
# k1: [1 2]
# k2: [2, 3]
# For n_clusters = 3 The average silhouette_score is : 0.4407280676985771
# To be fixed len:  (2440,)
# While fix: For n_clusters = 3 The average silhouette_score is : 0.34000662807374976
# Score lowered, keeping previous iteration labels..
# >>> After fix: For n_clusters = 4 (including outliers). The average silhouette_score is : 0.4566214927414089
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# For n_clusters = 4 The average silhouette_score is : 0.378107366107184
# To be fixed len:  (1927,)
# While fix: For n_clusters = 4 The average silhouette_score is : 0.3449805662240636
# Score lowered, keeping previous iteration labels..
# >>> After fix: For n_clusters = 5 (including outliers). The average silhouette_score is : 0.38945086319235495
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# For n_clusters = 5 The average silhouette_score is : 0.3167876358294557
# To be fixed len:  (1187,)
# While fix: For n_clusters = 5 The average silhouette_score is : 0.32936111685817343
# To be fixed len:  (961,)
# While fix: For n_clusters = 5 The average silhouette_score is : 0.3235047534509663
# Score lowered, keeping previous iteration labels..
# >>> After fix: For n_clusters = 6 (including outliers). The average silhouette_score is : 0.35084893588704835
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# For n_clusters = 6 The average silhouette_score is : 0.3125951667044843
# To be fixed len:  (321,)
# While fix: For n_clusters = 6 The average silhouette_score is : 0.35584998156625886
# To be fixed len:  (131,)
# While fix: For n_clusters = 6 The average silhouette_score is : 0.3562368051212481
# >>> After fix: For n_clusters = 7 (including outliers). The average silhouette_score is : 0.3587392261856496
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# For n_clusters = 7 The average silhouette_score is : 0.28054958616496106
# To be fixed len:  (754,)
# While fix: For n_clusters = 7 The average silhouette_score is : 0.32209121129318263
# To be fixed len:  (639,)
# While fix: For n_clusters = 7 The average silhouette_score is : 0.3222754839418743
# >>> After fix: For n_clusters = 8 (including outliers). The average silhouette_score is : 0.3332873958818892
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# For n_clusters = 9 The average silhouette_score is : 0.2920364490526943
# To be fixed len:  (292,)
# While fix: For n_clusters = 9 The average silhouette_score is : 0.324940076915603
# To be fixed len:  (268,)
# While fix: For n_clusters = 9 The average silhouette_score is : 0.32591180643892714
# >>> After fix: For n_clusters = 9 (including outliers). The average silhouette_score is : 0.3309751898709656
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 39 40 54 55]
# k2: [16, 17]
# For n_clusters = 11 The average silhouette_score is : 0.2928083991008779
# To be fixed len:  (468,)
# While fix: For n_clusters = 11 The average silhouette_score is : 0.3201287765921944
# To be fixed len:  (313,)
# While fix: For n_clusters = 11 The average silhouette_score is : 0.31857709001521867
# Score lowered, keeping previous iteration labels..
# >>> After fix: For n_clusters = 10 (including outliers). The average silhouette_score is : 0.3283964794093179
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 39 40 54 55]
# k2: [16, 17]
# k1: [ 1  5 11 29 30 39 40 54 55 72 73]
# k2: [13, 14]
# For n_clusters = 12 The average silhouette_score is : 0.2761572775936626
# To be fixed len:  (884,)
# While fix: For n_clusters = 12 The average silhouette_score is : 0.2987775140924577
# To be fixed len:  (945,)
# While fix: For n_clusters = 12 The average silhouette_score is : 0.2952967220290714
# Score lowered, keeping previous iteration labels..
# >>> After fix: For n_clusters = 11 (including outliers). The average silhouette_score is : 0.31075829280543904
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 39 40 54 55]
# k2: [16, 17]
# k1: [ 1  5 11 29 30 39 40 54 55 72 73]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 40 54 55 72 73 87 88]
# k2: [25, 26]
# For n_clusters = 13 The average silhouette_score is : 0.25137036877693864
# To be fixed len:  (1348,)
# While fix: For n_clusters = 13 The average silhouette_score is : 0.2902778195615006
# To be fixed len:  (1132,)
# While fix: For n_clusters = 13 The average silhouette_score is : 0.2932579210395228
# To be fixed len:  (1075,)
# While fix: For n_clusters = 13 The average silhouette_score is : 0.2943213241692003
# >>> After fix: For n_clusters = 12 (including outliers). The average silhouette_score is : 0.3124709783385032
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 39 40 54 55]
# k2: [16, 17]
# k1: [ 1  5 11 29 30 39 40 54 55 72 73]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 40 54 55 72 73 87 88]
# k2: [25, 26]
# k1: [  1   5  11  29  30  40  55  72  73  87  88 114 115]
# k2: [28, 29]
# For n_clusters = 14 The average silhouette_score is : 0.2564795266300811
# To be fixed len:  (946,)
# While fix: For n_clusters = 14 The average silhouette_score is : 0.29749788074882555
# To be fixed len:  (784,)
# While fix: For n_clusters = 14 The average silhouette_score is : 0.2978157211153842
# >>> After fix: For n_clusters = 13 (including outliers). The average silhouette_score is : 0.3102042225592374
# k1: [1 2]
# k2: [2, 3]
# k1: [1 5 6]
# k2: [4, 5]
# k1: [ 1  5 11 12]
# k2: [6, 7]
# k1: [ 1  5 11 19 20]
# k2: [8, 9]
# k1: [ 1  5 11 19 29 30]
# k2: [8, 9]
# k1: [ 1  5 11 29 30 39 40]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 39 40 54 55]
# k2: [16, 17]
# k1: [ 1  5 11 29 30 39 40 54 55 72 73]
# k2: [13, 14]
# k1: [ 1  5 11 29 30 40 54 55 72 73 87 88]
# k2: [25, 26]
# k1: [  1   5  11  29  30  40  55  72  73  87  88 114 115]
# k2: [28, 29]
# k1: [  1   5  11  29  30  40  55  72  73  87  88 114 144 145]
# k2: [42, 43]
# For n_clusters = 15 The average silhouette_score is : 0.26169119179295375
# To be fixed len:  (1195,)
# While fix: For n_clusters = 15 The average silhouette_score is : 0.31628834110944476
# To be fixed len:  (1203,)
# While fix: For n_clusters = 15 The average silhouette_score is : 0.3186104770054265
# >>> After fix: For n_clusters = 14 (including outliers). The average silhouette_score is : 0.3407522547156288
# /content/drive/MyDrive/MIDA2/IntelligentMobilityProject/Code/metrics/elbow.py:18: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# For n_clusters = 2 The average silhouette_score is : 0.6858174526302973
# k1: [1 2]
# k2: [3, 4]
# For n_clusters = 4 The average silhouette_score is : 0.378107366107184
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# For n_clusters = 5 The average silhouette_score is : 0.2777610664782623
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# k1: [ 1  6  7 11 12]
# k2: [5, 6]
# For n_clusters = 6 The average silhouette_score is : 0.2630477283540716
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# k1: [ 1  6  7 11 12]
# k2: [5, 6]
# k1: [ 1  6  7 11 18 19]
# k2: [5, 6]
# For n_clusters = 7 The average silhouette_score is : 0.24882116237562607
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# k1: [ 1  6  7 11 12]
# k2: [5, 6]
# k1: [ 1  6  7 11 18 19]
# k2: [5, 6]
# k1: [ 1  6  7 18 19 25 26]
# k2: [10, 11]
# For n_clusters = 9 The average silhouette_score is : 0.24147764990406032
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# k1: [ 1  6  7 11 12]
# k2: [5, 6]
# k1: [ 1  6  7 11 18 19]
# k2: [5, 6]
# k1: [ 1  6  7 18 19 25 26]
# k2: [10, 11]
# k1: [ 1  6  7 18 19 25 26 37 38]
# k2: [10, 11]
# For n_clusters = 10 The average silhouette_score is : 0.24328905779156737
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# k1: [ 1  6  7 11 12]
# k2: [5, 6]
# k1: [ 1  6  7 11 18 19]
# k2: [5, 6]
# k1: [ 1  6  7 18 19 25 26]
# k2: [10, 11]
# k1: [ 1  6  7 18 19 25 26 37 38]
# k2: [10, 11]
# k1: [ 1  6  7 19 25 26 37 38 49 50]
# k2: [10, 11]
# For n_clusters = 12 The average silhouette_score is : 0.23350417068076393
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# k1: [ 1  6  7 11 12]
# k2: [5, 6]
# k1: [ 1  6  7 11 18 19]
# k2: [5, 6]
# k1: [ 1  6  7 18 19 25 26]
# k2: [10, 11]
# k1: [ 1  6  7 18 19 25 26 37 38]
# k2: [10, 11]
# k1: [ 1  6  7 19 25 26 37 38 49 50]
# k2: [10, 11]
# k1: [ 1  6  7 19 25 26 37 38 49 50 61 62]
# k2: [20, 21]
# For n_clusters = 13 The average silhouette_score is : 0.225560037245721
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# k1: [ 1  6  7 11 12]
# k2: [5, 6]
# k1: [ 1  6  7 11 18 19]
# k2: [5, 6]
# k1: [ 1  6  7 18 19 25 26]
# k2: [10, 11]
# k1: [ 1  6  7 18 19 25 26 37 38]
# k2: [10, 11]
# k1: [ 1  6  7 19 25 26 37 38 49 50]
# k2: [10, 11]
# k1: [ 1  6  7 19 25 26 37 38 49 50 61 62]
# k2: [20, 21]
# k1: [ 1  6  7 19 25 26 37 38 50 61 62 83 84]
# k2: [15, 16]
# For n_clusters = 15 The average silhouette_score is : 0.23649057410398128
# For n_clusters = 2 The average silhouette_score is : 0.6858174526302973
# >>> After fix: For n_clusters = 2 (including outliers). The average silhouette_score is : 0.6858174526302973
# k1: [1 2]
# k2: [3, 4]
# For n_clusters = 4 The average silhouette_score is : 0.378107366107184
# To be fixed len:  (1927,)
# While fix: For n_clusters = 4 The average silhouette_score is : 0.3449805662240636
# Score lowered, keeping previous iteration labels..
# >>> After fix: For n_clusters = 5 (including outliers). The average silhouette_score is : 0.38945086319235495
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# For n_clusters = 5 The average silhouette_score is : 0.2777610664782623
# To be fixed len:  (1350,)
# While fix: For n_clusters = 5 The average silhouette_score is : 0.3033492802927199
# To be fixed len:  (1201,)
# While fix: For n_clusters = 5 The average silhouette_score is : 0.3084526413098939
# To be fixed len:  (978,)
# While fix: For n_clusters = 5 The average silhouette_score is : 0.31118437161582907
# >>> After fix: For n_clusters = 6 (including outliers). The average silhouette_score is : 0.33303487428561374
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# k1: [ 1  6  7 11 12]
# k2: [5, 6]
# For n_clusters = 6 The average silhouette_score is : 0.2630477283540716
# To be fixed len:  (1727,)
# While fix: For n_clusters = 6 The average silhouette_score is : 0.29986215440711744
# To be fixed len:  (901,)
# While fix: For n_clusters = 6 The average silhouette_score is : 0.3093553180299116
# To be fixed len:  (1039,)
# While fix: For n_clusters = 6 The average silhouette_score is : 0.3103526821343186
# >>> After fix: For n_clusters = 7 (including outliers). The average silhouette_score is : 0.3325815333652042
# k1: [1 2]
# k2: [3, 4]
# k1: [1 2 6 7]
# k2: [3, 4]
# k1: [ 1  6  7 11 12]
# k2: [5, 6]
# k1: [ 1  6  7 11 18 19]
# k2: [5, 6]
# For n_clusters = 7 The average silhouette_score is : 0.24882116237562607
# To be fixed len:  (1809,)
# While fix: For n_clusters = 7 The average silhouette_score is : 0.29173165217574404

# %% [markdown]
# # Good results

# %% [markdown]
# ## VDM5
#
# |Link|Cuts|(No postprocessing) Sil Avg|(Postprocessing) Sil Avg|Outliers|
# |------|-----|-----|-----|----|
# |average|[2,3,5,7,9]|  0.31| 0.36 |131|
# |average|[2,3,5,7,9,12]|  0.28| 0.33 |639|
# |complete|[2,4]|  0.30| 0.34 |355|
# |complete|[2,4,6]|  0.26| 0.33 |685|
# |complete|[2,4,6,8]|  0.26| 0.3 |151|
# |single|[2,4,6,33,49]|  0.367| 0.376 |600|
# |weighted|[2,4,6,8]|  0.26| 0.33 |1039|
# |weighted|[2,4,6,8,11]|  0.24| 0.33 |1480|

# %% [markdown]
# ## VDM6
#
# |Link|Cuts|(No postprocessing) Sil Avg|(Postprocessing) Sil Avg|Outliers|
# |------|-----|-----|-----|----|
# |average|[2,3,5,7,9]|  0.31| 0.35 |160|
# |complete|[2,3,5]|  0.24| 0.30 |211|
# |weighted|[2,4,6,8,11,13]|  0.25| 0.33 |532|
