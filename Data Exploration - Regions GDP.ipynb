# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Intelligent Mobility

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import skew
from scipy.stats import norm
from scipy.stats.stats import pearsonr
# %matplotlib inline
import sys
sys.path.append('/content/drive/MyDrive/MIDA2/')

# %%
# import dataset
ds_path = "/content/drive/MyDrive/MIDA2/IntelligentMobilityProject/Survey+dataset/macro_regions_per_country/regional_grouping.csv"

rg_df = pd.read_csv(ds_path) # region groups
rg_df

# %% [markdown]
# Lui prende un tot di persone dal nord dal centro e dal sud
# pero' non tiene conto di cosa? non tiene conto che se prende piu' persone dal nord, sta prendendo piu' persone
#
# dobbiamo controllare che il rapporto in base alla regione sia equo
